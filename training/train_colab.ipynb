# %% [markdown]
# # Shutdown-Gym — GRPO Training (Colab)
#
# TODO (Phase 13): end-to-end Colab notebook judges can rerun, per PROJECT.md Section 16.
#
# Scaffold only — implementation comes during Phase 13.
